# %%
import pandas as pd
soln = pd.read_csv('solution.csv',
                   header=None)

# %%
soln.rename(columns = {0:'streetId', 1:'count_2015', 2:'count_2016', 3:'count_2017', 
                          4:'count_2018', 5:'count_2019', 6:'coef'}, inplace=True)

# %%
soln
# Out:
#         streetId  count_2015  count_2016  count_2017  count_2018  count_2019  \
# 0           7299           0           2           0           0           2
# 1          77779         148         160         159          70         114
# 2           5964          76         107          94          41          83
# 3          98279           8          11          25           4           8
# 4          35431           0           2           5           1           1
# ...          ...         ...         ...         ...         ...         ...
# 119796     13329           2           0           5           1           1
# 119797     55011          69          64          57          27          82
# 119798     87758           2           1           1           1           2
# 119799     53534           0           0           0           0           0
# 119800     89339           0           0           1           1           3
#
#         coef
# 0        0.2
# 1      -15.8
# ...

# %%
ct2015 = pd.to_numeric(soln.count_2015).sum()
ct2016 = pd.to_numeric(soln.count_2016).sum()
ct2017 = pd.to_numeric(soln.count_2017).sum()
ct2018 = pd.to_numeric(soln.count_2018).sum()
ct2019 = pd.to_numeric(soln.count_2019).sum()

# %%
ct2015+ct2016+ct2017+ct2018+ct2019
# Out:
# 37194411

# %%
soln.sort_values(['coef'])
# Out:
#        streetId  count_2015  count_2016  count_2017  count_2018  count_2019  \
# 18531      3557       56619       60550       60672       26200       63411
# 28555    155823       16104       18820       15525        6213       16360
# 17897      2723       32103       35936       34545       15927       36972
# 8843     131837        4791        5440        5494        2796        2648
# 34403    174138        7164        8743        7700        3246        6698
# ...         ...         ...         ...         ...         ...         ...
# 49671     19734        1222         380        1172         865        2814
# 55195     19563        1336        3809        6324         719        4746
# 83573    141407         155         329         481         213        2412
# 6279       1379        1667        2315        3910        1575        4306
# 48994      1731        1155        2077        1981        1311        9035
#
#          coef
# 18531 -2076.6
# 28555 -1209.5
# ...
